# %%
# !pip install roboflow
# !pip install ultralytics -q
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.64-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.1.64-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 4.4 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.0 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 roboflow-1.1.64
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.0 MB/s eta 0:00:00

# %%
from google.colab import drive
from ultralytics import YOLO
import os
import cv2
import numpy as np
from glob import glob
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Nieuwe outputmap Drive
data_path = "/content/drive/MyDrive/roboflow_dataset_detectie"
os.makedirs(data_path, exist_ok=True)

os.chdir(data_path)

# %%
# Dataset roboflow
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pDX5tjADYL9oViENUvwf")
project = rf.workspace("tata-steel-zabde").project("amr2-yviht")
version = project.version(9)
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.64)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in AMR2-9 to yolov11:: 100%|██████████| 63999/63999 [00:06<00:00, 9452.79it/s]
# Extracting Dataset Version Zip to AMR2-9 in yolov11:: 100%|██████████| 2896/2896 [00:37<00:00, 77.52it/s]

# %%
data_yaml_path = "/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/data.yaml"

# %%
model_path = "/content/detectie_model.tflite"
model = YOLO(model_path, task='detect')

# %%
print(model.names)
print("Aantal klassen:", len(model.names))
# Out:
# Loading /content/detectie_model.tflite for TensorFlow Lite inference...
# {0: 'display'}
# Aantal klassen: 1

# %% [markdown]
# # Validatie

# %%
# AP op validatie
metrics_val = model.val(data=data_yaml_path, split='val', imgsz=160, save=False, save_json=False, save_txt=True, plots=False)
print("Validatie-resultaten:")
mp, mr, map50, map = metrics_val.box.mean_results()
print(f"mAP@0.5: {map50:.4f}")
print(f"mAP@0.5:0.95: {map:.4f}")
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Loading /content/detectie_model.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 160, 160)
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 8.5±3.0 MB/s, size: 33.8 KB)
# val: Scanning /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/valid/labels... 287 images, 5 backgrounds, 0 corrupt: 100%|██████████| 287/287 [00:06<00:00, 47.44it/s]
# val: New cache created: /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 287/287 [00:13<00:00, 21.65it/s]
#                    all        287        286      0.985      0.943      0.985      0.661
# Speed: 0.2ms preprocess, 15.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Validatie-resultaten:
# mAP@0.5: 0.9847
# mAP@0.5:0.95: 0.6614

# %%
float = __builtins__.float
int = __builtins__.int

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    boxBArea = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])
    return interArea / (boxAArea + boxBArea - interArea + 1e-6)

# Pad-instellingen
img_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/valid/images'
label_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/valid/labels'
output_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/mismatches_val'
os.makedirs(output_dir, exist_ok=True)

image_paths = glob(os.path.join(img_dir, '*.jpg'))

true_positives = 0
total_gt_boxes = 0
iou_threshold = 0.5

for img_path in image_paths:
    filename = os.path.splitext(os.path.basename(img_path))[0]
    label_path = os.path.join(label_dir, filename + '.txt')

    # Lees afbeelding
    img = cv2.imread(img_path)
    height, width = img.shape[:2]

    # Voorspelling
    results = model(img)
    boxes = results[0].boxes

    if boxes is None or len(boxes) == 0:
        continue

    # Kies box met hoogste confidence
    confs = boxes.conf.cpu().numpy()
    idx_best = np.argmax(confs)
    pred_box = boxes.xyxy[idx_best].cpu().numpy()

    # Laad ground truth
    if not os.path.exists(label_path):
        continue

    with open(label_path, 'r') as f:
        lines = f.readlines()

    gt_boxes = []
    for line in lines:
        parts = [float(x) for x in line.strip().split()]
        if len(parts) != 5:
            continue
        cls, x_c, y_c, w, h = parts
        x1 = (x_c - w / 2) * width
        y1 = (y_c - h / 2) * height
        x2 = (x_c + w / 2) * width
        y2 = (y_c + h / 2) * height
        gt_boxes.append([x1, y1, x2, y2])

    total_gt_boxes += len(gt_boxes)

    # Vergelijk voorspelling met GT-boxen
    match_found = any(iou(pred_box, gt_box) >= iou_threshold for gt_box in gt_boxes)
    if match_found:
        true_positives += 1
    else:
        # Teken GT-boxen (groen)
        for gt in gt_boxes:
            gx1, gy1, gx2, gy2 = [int(x) for x in gt]
            cv2.rectangle(img, (gx1, gy1), (gx2, gy2), (0, 255, 0), 2)

        # Teken voorspelde box (rood)
        px1, py1, px2, py2 = [int(x) for x in pred_box]
        cv2.rectangle(img, (px1, py1), (px2, py2), (0, 0, 255), 2)

        # Sla mismatch-afbeelding op
        save_path = os.path.join(output_dir, f'{filename}_mismatch.jpg')
        cv2.imwrite(save_path, img)

# Bereken recall
recall = true_positives / total_gt_boxes if total_gt_boxes > 0 else 0
print(f"Handmatig berekende recall: {recall:.4f}")
print(f"Mismatches opgeslagen in map: {output_dir}")
# Out:
# 0: 160x160 (no detections), 21.1ms
# Speed: 1.7ms preprocess, 21.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 30.9ms
# Speed: 1.3ms preprocess, 30.9ms inference, 5.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.1ms
# Speed: 0.9ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.3ms
# Speed: 0.9ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 0.9ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 0.9ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 0.8ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.4ms
# Speed: 0.7ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 0.8ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 0.8ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.7ms
# Speed: 0.8ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.0ms
# Speed: 0.9ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.5ms
# Speed: 0.9ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.8ms
# Speed: 1.2ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 0.9ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 1.1ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 0.8ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 0.8ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 0.9ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.1ms
# Speed: 0.8ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.7ms
# Speed: 1.3ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.2ms
# Speed: 1.7ms preprocess, 19.2ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 4.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 27.3ms
# Speed: 0.8ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.9ms
# Speed: 0.8ms preprocess, 17.9ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 42.3ms
# Speed: 0.8ms preprocess, 42.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 38.5ms
# Speed: 2.3ms preprocess, 38.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 35.9ms
# Speed: 3.7ms preprocess, 35.9ms inference, 7.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.7ms
# Speed: 0.8ms preprocess, 23.7ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.5ms
# Speed: 0.8ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.5ms
# Speed: 0.9ms preprocess, 17.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 26.9ms
# Speed: 0.9ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 40.8ms
# Speed: 0.8ms preprocess, 40.8ms inference, 5.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 33.6ms
# Speed: 0.8ms preprocess, 33.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.7ms
# Speed: 0.9ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.2ms
# Speed: 0.8ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 31.6ms
# Speed: 4.2ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.6ms
# Speed: 0.9ms preprocess, 17.6ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 0.8ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.8ms
# Speed: 1.2ms preprocess, 17.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.4ms
# Speed: 0.9ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.3ms
# Speed: 0.9ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.3ms
# Speed: 0.8ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 1.1ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.4ms
# Speed: 0.8ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.7ms
# Speed: 0.8ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.1ms
# Speed: 0.9ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 0.8ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.4ms
# Speed: 0.8ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.3ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 0.9ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.2ms
# Speed: 0.9ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.1ms
# Speed: 0.9ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.1ms
# Speed: 2.6ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.1ms
# Speed: 0.9ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 0.9ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.9ms preprocess, 19.8ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 18.9ms
# Speed: 0.9ms preprocess, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.3ms
# Speed: 0.8ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.8ms preprocess, 18.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.1ms
# Speed: 0.8ms preprocess, 18.1ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.6ms
# Speed: 0.8ms preprocess, 22.6ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.5ms
# Speed: 0.8ms preprocess, 20.5ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.3ms
# Speed: 0.8ms preprocess, 19.3ms inference, 4.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.8ms preprocess, 20.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.2ms
# Speed: 0.9ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.2ms
# Speed: 0.9ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.5ms
# Speed: 0.9ms preprocess, 19.5ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.0ms
# Speed: 0.8ms preprocess, 19.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.7ms
# Speed: 0.9ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.7ms
# Speed: 0.8ms preprocess, 19.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.5ms
# Speed: 0.9ms preprocess, 23.5ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 0.9ms preprocess, 19.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.8ms
# Speed: 0.8ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.7ms
# Speed: 0.9ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 0.8ms preprocess, 21.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.8ms preprocess, 18.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.4ms
# Speed: 0.8ms preprocess, 23.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.0ms
# Speed: 0.8ms preprocess, 19.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.9ms
# Speed: 0.8ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.7ms
# Speed: 0.8ms preprocess, 17.7ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 22.0ms
# Speed: 0.8ms preprocess, 22.0ms inference, 3.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.4ms
# Speed: 0.8ms preprocess, 25.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.6ms
# Speed: 0.9ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.7ms
# Speed: 0.9ms preprocess, 20.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.2ms
# Speed: 0.8ms preprocess, 19.2ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.3ms
# Speed: 0.8ms preprocess, 19.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.0ms
# Speed: 0.8ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.9ms
# Speed: 0.8ms preprocess, 21.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 3.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.9ms preprocess, 18.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.8ms
# Speed: 0.8ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.9ms preprocess, 20.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 19.5ms
# Speed: 0.8ms preprocess, 19.5ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.5ms
# Speed: 0.8ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 23.7ms
# Speed: 0.8ms preprocess, 23.7ms inference, 0.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 22.2ms
# Speed: 0.8ms preprocess, 22.2ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 22.3ms
# Speed: 0.8ms preprocess, 22.3ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 24.7ms
# Speed: 2.2ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.6ms
# Speed: 0.8ms preprocess, 24.6ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 3 displays, 28.6ms
# Speed: 0.8ms preprocess, 28.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.1ms
# Speed: 0.8ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.8ms preprocess, 20.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 18.2ms
# Speed: 0.8ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.4ms
# Speed: 0.8ms preprocess, 19.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.4ms
# Speed: 0.8ms preprocess, 19.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.8ms preprocess, 18.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.4ms
# Speed: 1.5ms preprocess, 19.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.6ms
# Speed: 0.8ms preprocess, 18.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.8ms preprocess, 20.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.6ms
# Speed: 0.8ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.6ms
# Speed: 0.8ms preprocess, 23.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.0ms
# Speed: 0.9ms preprocess, 19.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.6ms
# Speed: 0.9ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.7ms
# Speed: 0.8ms preprocess, 19.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.7ms
# Speed: 0.8ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 0.8ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 0.8ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.4ms
# Speed: 0.8ms preprocess, 19.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.2ms
# Speed: 0.8ms preprocess, 18.2ms inference, 4.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 21.7ms
# Speed: 0.8ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 0.8ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.0ms
# Speed: 0.8ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.9ms
# Speed: 0.8ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 3 displays, 18.2ms
# Speed: 0.9ms preprocess, 18.2ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.1ms
# Speed: 0.8ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.9ms
# Speed: 0.8ms preprocess, 16.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.1ms
# Speed: 0.8ms preprocess, 19.1ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.0ms
# Speed: 0.8ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.3ms
# Speed: 0.8ms preprocess, 21.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.2ms
# Speed: 0.8ms preprocess, 19.2ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.7ms
# Speed: 0.9ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 3 displays, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.9ms
# Speed: 0.9ms preprocess, 20.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.4ms
# Speed: 1.0ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 1.1ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.9ms preprocess, 18.5ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.6ms
# Speed: 0.8ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 0.8ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.6ms
# Speed: 0.9ms preprocess, 17.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.1ms
# Speed: 0.9ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.2ms
# Speed: 0.8ms preprocess, 20.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.0ms
# Speed: 1.8ms preprocess, 24.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 20.3ms
# Speed: 0.8ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.5ms
# Speed: 0.9ms preprocess, 19.5ms inference, 2.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.2ms
# Speed: 0.8ms preprocess, 19.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.8ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.6ms
# Speed: 0.9ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.6ms
# Speed: 0.9ms preprocess, 19.6ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 0.8ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 0.9ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 0.8ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.5ms
# Speed: 1.4ms preprocess, 14.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.2ms
# Speed: 0.8ms preprocess, 12.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.5ms
# Speed: 1.1ms preprocess, 13.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.5ms
# Speed: 0.9ms preprocess, 20.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.7ms
# Speed: 1.2ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.6ms
# Speed: 0.9ms preprocess, 14.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 0.9ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 0.9ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 12.0ms
# Speed: 1.2ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 0.9ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 0.8ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 1.2ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 0.9ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.9ms preprocess, 18.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 18.3ms
# Speed: 0.9ms preprocess, 18.3ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 0.9ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.3ms
# Speed: 0.8ms preprocess, 13.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.7ms
# Speed: 1.2ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.7ms
# Speed: 0.9ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 0.9ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.7ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.7ms
# Speed: 0.7ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 0.9ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.3ms
# Speed: 0.8ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 0.8ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.8ms
# Speed: 0.9ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.6ms
# Speed: 1.3ms preprocess, 19.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 0.9ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 0.9ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.0ms
# Speed: 1.2ms preprocess, 19.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.1ms
# Speed: 1.3ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.2ms
# Speed: 0.8ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 11.0ms
# Speed: 0.8ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 0.8ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 0.8ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 0.9ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# Handmatig berekende recall: 0.9645
# Mismatches opgeslagen in map: /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/mismatches_val

# %% [markdown]
# # Recall: 96.45

# %% [markdown]
# # Test

# %%
# AP op validatie
metrics_val = model.val(data=data_yaml_path, split='test', imgsz=160, save=False, save_json=False, save_txt=True, plots=False)
print("test-resultaten:")
mp, mr, map50, map = metrics_val.box.mean_results()
print(f"mAP@0.5: {map50:.4f}")
print(f"mAP@0.5:0.95: {map:.4f}")
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Loading /content/detectie_model.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 160, 160)
# val: Fast image access ✅ (ping: 1.0±0.9 ms, read: 14.4±6.6 MB/s, size: 55.9 KB)
# val: Scanning /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/test/labels... 290 images, 4 backgrounds, 0 corrupt: 100%|██████████| 290/290 [00:04<00:00, 70.48it/s]
# val: New cache created: /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 288. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 290/290 [00:18<00:00, 15.44it/s]
#                    all        290        288      0.964      0.934      0.979      0.654
# Speed: 0.3ms preprocess, 26.2ms inference, 0.0ms loss, 2.0ms postprocess per image
# test-resultaten:
# mAP@0.5: 0.9788
# mAP@0.5:0.95: 0.6535

# %%
float = __builtins__.float
int = __builtins__.int

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    boxBArea = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])
    return interArea / (boxAArea + boxBArea - interArea + 1e-6)

# Pad-instellingen
img_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/test/images'
label_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/test/labels'
output_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/mismatches_test'
os.makedirs(output_dir, exist_ok=True)

image_paths = glob(os.path.join(img_dir, '*.jpg'))

true_positives = 0
total_gt_boxes = 0
iou_threshold = 0.5

for img_path in image_paths:
    filename = os.path.splitext(os.path.basename(img_path))[0]
    label_path = os.path.join(label_dir, filename + '.txt')

    # Lees afbeelding
    img = cv2.imread(img_path)
    height, width = img.shape[:2]

    # Voorspelling
    results = model(img)
    boxes = results[0].boxes

    if boxes is None or len(boxes) == 0:
        continue

    # Kies box met hoogste confidence
    confs = boxes.conf.cpu().numpy()
    idx_best = np.argmax(confs)
    pred_box = boxes.xyxy[idx_best].cpu().numpy()

    # Laad ground truth
    if not os.path.exists(label_path):
        continue

    with open(label_path, 'r') as f:
        lines = f.readlines()

    gt_boxes = []
    for line in lines:
        parts = [float(x) for x in line.strip().split()]
        if len(parts) != 5:
            continue
        cls, x_c, y_c, w, h = parts
        x1 = (x_c - w / 2) * width
        y1 = (y_c - h / 2) * height
        x2 = (x_c + w / 2) * width
        y2 = (y_c + h / 2) * height
        gt_boxes.append([x1, y1, x2, y2])

    total_gt_boxes += len(gt_boxes)

    # Vergelijk voorspelling met GT-boxen
    match_found = any(iou(pred_box, gt_box) >= iou_threshold for gt_box in gt_boxes)
    if match_found:
        true_positives += 1
    else:
        # Teken GT-boxen (groen)
        for gt in gt_boxes:
            gx1, gy1, gx2, gy2 = [int(x) for x in gt]
            cv2.rectangle(img, (gx1, gy1), (gx2, gy2), (0, 255, 0), 2)

        # Teken voorspelde box (rood)
        px1, py1, px2, py2 = [int(x) for x in pred_box]
        cv2.rectangle(img, (px1, py1), (px2, py2), (0, 0, 255), 2)

        # Sla mismatch-afbeelding op
        save_path = os.path.join(output_dir, f'{filename}_mismatch.jpg')
        cv2.imwrite(save_path, img)

# Bereken recall
recall = true_positives / total_gt_boxes if total_gt_boxes > 0 else 0
print(f"Handmatig berekende recall: {recall:.4f}")
print(f"Mismatches opgeslagen in map: {output_dir}")
# Out:
# 0: 160x160 1 display, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.1ms
# Speed: 0.8ms preprocess, 19.1ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.5ms
# Speed: 0.9ms preprocess, 19.5ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.4ms
# Speed: 0.8ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.7ms
# Speed: 0.8ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.6ms
# Speed: 0.8ms preprocess, 18.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.2ms
# Speed: 0.8ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.7ms
# Speed: 0.9ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 0.8ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 0.9ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 0.9ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 0.6ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.4ms
# Speed: 0.8ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 0.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.7ms
# Speed: 0.9ms preprocess, 15.7ms inference, 5.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.0ms
# Speed: 0.9ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 0.9ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 0.7ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 1.1ms preprocess, 12.6ms inference, 2.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 1.1ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 0.9ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.5ms
# Speed: 0.9ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 1.1ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 1.2ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.2ms
# Speed: 0.8ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.1ms
# Speed: 0.9ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.6ms
# Speed: 0.9ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.8ms
# Speed: 0.8ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.3ms
# Speed: 0.8ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.0ms
# Speed: 1.3ms preprocess, 14.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.0ms
# Speed: 0.9ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.9ms
# Speed: 1.1ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.3ms
# Speed: 1.2ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.4ms
# Speed: 1.3ms preprocess, 14.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.3ms
# Speed: 0.8ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 11.4ms
# Speed: 0.9ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.1ms
# Speed: 2.3ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.2ms
# Speed: 0.9ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 1.3ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 1.2ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.4ms
# Speed: 2.6ms preprocess, 21.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 26.3ms
# Speed: 0.9ms preprocess, 26.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 3.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 39.3ms
# Speed: 3.6ms preprocess, 39.3ms inference, 2.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.5ms
# Speed: 1.7ms preprocess, 28.5ms inference, 2.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 31.5ms
# Speed: 2.7ms preprocess, 31.5ms inference, 5.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 30.4ms
# Speed: 1.5ms preprocess, 30.4ms inference, 4.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.2ms
# Speed: 3.5ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 17.7ms
# Speed: 1.2ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.7ms
# Speed: 1.5ms preprocess, 15.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 14.7ms
# Speed: 0.8ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.7ms
# Speed: 0.9ms preprocess, 25.7ms inference, 3.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 21.4ms
# Speed: 3.6ms preprocess, 21.4ms inference, 3.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.2ms
# Speed: 2.9ms preprocess, 23.2ms inference, 3.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.2ms
# Speed: 2.5ms preprocess, 22.2ms inference, 2.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 42.8ms
# Speed: 3.3ms preprocess, 42.8ms inference, 3.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.0ms
# Speed: 1.8ms preprocess, 23.0ms inference, 2.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.6ms
# Speed: 1.9ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 5 displays, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 3.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.6ms
# Speed: 1.8ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.9ms
# Speed: 2.3ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 2.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 46.7ms
# Speed: 2.1ms preprocess, 46.7ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.0ms
# Speed: 1.3ms preprocess, 18.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 29.8ms
# Speed: 0.8ms preprocess, 29.8ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.1ms
# Speed: 1.2ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 17.5ms
# Speed: 3.3ms preprocess, 17.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 16.0ms
# Speed: 1.3ms preprocess, 16.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 14.4ms
# Speed: 1.1ms preprocess, 14.4ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.7ms
# Speed: 1.3ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.8ms
# Speed: 0.9ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.3ms
# Speed: 1.8ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.4ms
# Speed: 1.6ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 26.2ms
# Speed: 4.8ms preprocess, 26.2ms inference, 5.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.7ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.2ms
# Speed: 1.1ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.5ms
# Speed: 1.3ms preprocess, 23.5ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.2ms
# Speed: 1.2ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 3 displays, 14.2ms
# Speed: 0.9ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.9ms
# Speed: 1.3ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.4ms
# Speed: 1.6ms preprocess, 22.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.7ms
# Speed: 1.2ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 32.3ms
# Speed: 2.6ms preprocess, 32.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.4ms
# Speed: 0.8ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 16.3ms
# Speed: 4.5ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 3 displays, 21.6ms
# Speed: 2.3ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 3.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.8ms
# Speed: 1.1ms preprocess, 14.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.4ms
# Speed: 0.9ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.4ms
# Speed: 0.8ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.2ms
# Speed: 0.9ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 4.4ms preprocess, 18.4ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.1ms
# Speed: 0.9ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.0ms
# Speed: 1.7ms preprocess, 24.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.9ms
# Speed: 0.9ms preprocess, 22.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 2.5ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.6ms
# Speed: 0.9ms preprocess, 14.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.8ms
# Speed: 0.9ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.8ms
# Speed: 0.9ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.7ms
# Speed: 0.8ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 13.4ms
# Speed: 1.1ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 1.1ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.6ms
# Speed: 0.8ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.4ms
# Speed: 1.4ms preprocess, 19.4ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 29.8ms
# Speed: 1.2ms preprocess, 29.8ms inference, 3.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.9ms
# Speed: 1.1ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 14.2ms
# Speed: 1.4ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.6ms
# Speed: 1.5ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 14.2ms
# Speed: 1.4ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.7ms
# Speed: 1.2ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 15.8ms
# Speed: 1.2ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 14.6ms
# Speed: 0.8ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 2.9ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 14.7ms
# Speed: 0.9ms preprocess, 14.7ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 5.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.2ms
# Speed: 3.1ms preprocess, 22.2ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 27.0ms
# Speed: 0.9ms preprocess, 27.0ms inference, 3.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 29.0ms
# Speed: 3.3ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 5.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 11.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 73.5ms
# Speed: 5.7ms preprocess, 73.5ms inference, 5.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 4.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 35.8ms
# Speed: 1.9ms preprocess, 35.8ms inference, 3.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 34.6ms
# Speed: 4.8ms preprocess, 34.6ms inference, 20.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 73.4ms
# Speed: 2.2ms preprocess, 73.4ms inference, 21.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 46.8ms
# Speed: 2.3ms preprocess, 46.8ms inference, 5.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 44.9ms
# Speed: 3.0ms preprocess, 44.9ms inference, 10.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 66.9ms
# Speed: 6.0ms preprocess, 66.9ms inference, 7.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 70.6ms
# Speed: 21.7ms preprocess, 70.6ms inference, 16.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.2ms
# Speed: 4.9ms preprocess, 20.2ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.1ms
# Speed: 0.8ms preprocess, 23.1ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.6ms
# Speed: 0.9ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.1ms
# Speed: 0.9ms preprocess, 28.1ms inference, 2.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.3ms
# Speed: 0.8ms preprocess, 28.3ms inference, 4.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 6.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 24.3ms
# Speed: 0.9ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.9ms
# Speed: 4.6ms preprocess, 21.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.5ms
# Speed: 4.3ms preprocess, 22.5ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 42.6ms
# Speed: 0.8ms preprocess, 42.6ms inference, 4.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 2 displays, 20.5ms
# Speed: 5.1ms preprocess, 20.5ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.1ms
# Speed: 0.9ms preprocess, 23.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.7ms
# Speed: 0.9ms preprocess, 28.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.5ms
# Speed: 0.9ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 28.3ms
# Speed: 0.9ms preprocess, 28.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.9ms
# Speed: 0.9ms preprocess, 22.9ms inference, 6.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.6ms
# Speed: 1.7ms preprocess, 23.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.0ms
# Speed: 0.9ms preprocess, 23.0ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 2.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.4ms
# Speed: 1.8ms preprocess, 20.4ms inference, 4.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 27.8ms
# Speed: 0.9ms preprocess, 27.8ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.1ms
# Speed: 1.5ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 31.7ms
# Speed: 0.9ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 2.2ms preprocess, 21.6ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 29.8ms
# Speed: 0.9ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.6ms
# Speed: 0.9ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.8ms
# Speed: 0.8ms preprocess, 19.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.9ms
# Speed: 0.8ms preprocess, 22.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.1ms
# Speed: 0.9ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.3ms
# Speed: 0.8ms preprocess, 22.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.8ms
# Speed: 0.9ms preprocess, 18.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 1.1ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.4ms
# Speed: 3.4ms preprocess, 21.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 25.8ms
# Speed: 0.9ms preprocess, 25.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.8ms
# Speed: 0.8ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.5ms
# Speed: 0.8ms preprocess, 19.5ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.3ms
# Speed: 1.6ms preprocess, 19.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.0ms
# Speed: 0.9ms preprocess, 23.0ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 1.2ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 18.5ms
# Speed: 0.9ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.0ms
# Speed: 0.8ms preprocess, 22.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.1ms
# Speed: 0.8ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 0.8ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.8ms
# Speed: 0.8ms preprocess, 18.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.2ms
# Speed: 0.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.3ms
# Speed: 0.9ms preprocess, 18.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.9ms
# Speed: 0.8ms preprocess, 18.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.8ms
# Speed: 0.9ms preprocess, 22.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 17.5ms
# Speed: 0.9ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 23.9ms
# Speed: 0.9ms preprocess, 23.9ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.6ms
# Speed: 0.8ms preprocess, 22.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.7ms
# Speed: 0.8ms preprocess, 22.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.3ms
# Speed: 0.8ms preprocess, 21.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.7ms
# Speed: 3.7ms preprocess, 18.7ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.0ms
# Speed: 0.9ms preprocess, 20.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 21.4ms
# Speed: 0.8ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.8ms
# Speed: 0.8ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.7ms
# Speed: 0.8ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.4ms
# Speed: 0.8ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 19.9ms
# Speed: 0.8ms preprocess, 19.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 26.5ms
# Speed: 0.8ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 18.9ms
# Speed: 1.1ms preprocess, 18.9ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
# Handmatig berekende recall: 0.9718
# Mismatches opgeslagen in map: /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/mismatches_test

# %% [markdown]
# # Recall: 97.18

# %%
import random

# Map met testafbeeldingen
img_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/test/images'
output_random_dir = '/content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/random_detectie'
os.makedirs(output_random_dir, exist_ok=True)

# Selecteer 10 willekeurige afbeeldingen
all_images = glob(os.path.join(img_dir, '*.jpg'))
random_images = random.sample(all_images, min(10, len(all_images)))

for img_path in random_images:
    filename = os.path.splitext(os.path.basename(img_path))[0]
    img = cv2.imread(img_path)

    results = model(img)
    boxes = results[0].boxes

    if boxes is not None and len(boxes) > 0:
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            conf = box.conf[0].item()
            cls_id = int(box.cls[0].item())
            label = f'{cls_id} {conf:.2f}'
            cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 255, 0), 2)
            cv2.putText(img, label, (int(x1), int(y1) - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 1)

    save_path = os.path.join(output_random_dir, f'{filename}_detectie.jpg')
    cv2.imwrite(save_path, img)

print(f"Willekeurige detecties opgeslagen in map: {output_random_dir}")
# Out:
# 0: 160x160 1 display, 15.6ms
# Speed: 0.9ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 0.9ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.7ms
# Speed: 0.8ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.4ms
# Speed: 0.8ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 display, 10.8ms
# Speed: 1.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# Willekeurige detecties opgeslagen in map: /content/drive/MyDrive/roboflow_dataset_detectie/AMR2-9/random_detectie
